# %%
pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Collecting google-api-python-client
#   Downloading https://files.pythonhosted.org/packages/80/0f/6cebce3b4708228344e7606cbb7dd957e989d8c533c590c1d6d818cfd4c2/google_api_python_client-2.30.0-py2.py3-none-any.whl (7.8MB)
# Requirement already up-to-date: google-auth-httplib2 in c:\programdata\anaconda3\lib\site-packages (0.1.0)
# Requirement already up-to-date: google-auth-oauthlib in c:\programdata\anaconda3\lib\site-packages (0.4.6)
# Requirement already satisfied, skipping upgrade: google-auth<3.0.0dev,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (2.3.3)
# Requirement already satisfied, skipping upgrade: google-api-core<3.0.0dev,>=1.21.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (2.2.2)
# Requirement already satisfied, skipping upgrade: uritemplate<5,>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied, skipping upgrade: httplib2<1dev,>=0.15.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-python-client) (0.20.2)
# Requirement already satisfied, skipping upgrade: six in c:\programdata\anaconda3\lib\site-packages (from google-auth-httplib2) (1.12.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.7.2)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.2.4)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (41.4.0)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.22.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.12.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (3.19.1)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.52.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (1.53.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2; python_version > "3.0" in c:\programdata\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (2.4.2)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2019.9.11)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (1.24.2)
# Installing collected packages: google-api-python-client
#   Found existing installation: google-api-python-client 2.29.0
#     Uninstalling google-api-python-client-2.29.0:
#       Successfully uninstalled google-api-python-client-2.29.0
# Successfully installed google-api-python-client-2.30.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build

# %%
import pandas as pd
import seaborn as sns

# %%
api_key='AIzaSyBEHRc90gHYRNAtYlbL2WHHd6XgmEndjwk'
channel_ids=['UCaDh-eU-lds_d9kS976vBVw', #Analyze with Ali
             'UCJublDh2UsiIKsAE1553miw', #Greg Hogg
             'UCq6XkhO5SZ66N04IcPbqNcw',#Keith Galli
            'UC6AVa0vSrCpuskzGDDKz_EQ'] #Zedstatistics

youtube=build('youtube','v3',developerKey=api_key)

# %% [markdown]
# # Function

# %%
def get_channel_statistics(youtube,channel_ids): #A dictionary from which we will have a look into the response object
    all_data=[]
    request=youtube.channels().list(
            part="snippet,contentDetails,statistics",
                id=','.join(channel_ids))
    response=request.execute()
    return response

# %%
a=get_channel_statistics(youtube,channel_ids)
a    # to have a better understanding , copy and paste the output into a JSON formatter
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '0P21OEQy6oJJ3P73Z2n-gw8OXh8',
#  'pageInfo': {'totalResults': 4, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'LSRQygr8Q6-ApWKqv3_iZotcBtU',
#    'id': 'UCJublDh2UsiIKsAE1553miw',
#    'snippet': {'title': 'Greg Hogg',
#     'description': "Looking to learn Data Science, Machine Learning, or Big Data?\n\nI'll help you master the content and land your dream job!\n\nSubscribe!\n",
#     'customUrl': 'greghogg',
#     'publishedAt': '2011-11-24T17:32:46Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/lM9D8KBNCGCuhtQR4xxU7073L6XfMK5qPyIo_dlh6muHQFVQO_Ij9SXEREisPIFFOYBPdbwpnw=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/lM9D8KBNCGCuhtQR4xxU7073L6XfMK5qPyIo_dlh6muHQFVQO_Ij9SXEREisPIFFOYBPdbwpnw=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/lM9D8KBNCGCuhtQR4xxU7073L6XfMK5qPyIo_dlh6muHQFVQO_Ij9SXEREisPIFFOYBPdbwpnw=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Greg Hogg',
#      'description': "Looking to learn Data Science, Machine Learning, or Big Data?\n\nI'll help you master the content and land your dream job!\n\nSubscribe!\n"},
#     'country': 'CA'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUJublDh2UsiIKsAE1553miw'}},
#    'statistics': {'viewCount': '213828',
#     'subscriberCount': '13000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '215'}},
#   {'kind': 'youtube#channel',
#    'etag': 'MzSdtmFg39G5gYzoBpxdIzCt7no',
#    'id': 'UCaDh-eU-lds_d9kS976vBVw',
#    'snippet': {'title': 'Analyze With Ali',
#     'description': "Hi there 🖐🏽\n\nMy name is Ali and I am a Data Analytics Manager located in Oslo, Norway. \n\nIronically I started out studying journalism, moved towards business and somehow ended up working in sales for a data analytics software company named Qlik in London. Since then I've been lucky enough to work as a Senior Sales Engineer, Lead Consultant, Team Lead and now working client side as a Data Analytics Manager in an international company.\n\nThis channel is something I do for fun to share my passion for teaching and sharing knowledge. If I wasn't doing what I am doing today, I think I would have been a teacher. The creativity I can pour into this channel makes me want to learn more, challenge myself and let me meet people from all over the world that also has a passion for data analytics.\n\nNo matter what you are looking don't hesitate to get involved, ask questions, give feedback or challenge yourself to learn something new! That is where the true fun is!\n\nAll the best,\n\nAli\n",
#     'customUrl': 'analyzewithali',
#     'publishedAt': '2019-10-19T16:50:36.317895Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRlIacTLqAUcD9ZG_xjlShx7CWuAaPX4aOdzE9F3A=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRlIacTLqAUcD9ZG_xjlShx7CWuAaPX4aOdzE9F3A=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRlIacTLqAUcD9ZG_xjlShx7CWuAaPX4aOdzE9F3A=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Analyze With Ali',
#      'description': "Hi there 🖐🏽\n\nMy name is Ali and I am a Data Analytics Manager located in Oslo, Norway. \n\nIronically I started out studying journalism, moved towards business and somehow ended up working in sales for a data analytics software company named Qlik in London. Since then I've been lucky enough to work as a Senior Sales Engineer, Lead Consultant, Team Lead and now working client side as a Data Analytics Manager in an international company.\n\nThis channel is something I do for fun to share my passion for teaching and sharing knowledge. If I wasn't doing what I am doing today, I think I would have been a teacher. The creativity I can pour into this channel makes me want to learn more, challenge myself and let me meet people from all over the world that also has a passion for data analytics.\n\nNo matter what you are looking don't hesitate to get involved, ask questions, give feedback or challenge yourself to learn something new! That is where the true fun is!\n\nAll the best,\n\nAli\n"},
#     'country': 'NO'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUaDh-eU-lds_d9kS976vBVw'}},
#    'statistics': {'viewCount': '257042',
#     'subscriberCount': '8370',
#     'hiddenSubscriberCount': False,
#     'videoCount': '55'}},
#   {'kind': 'youtube#channel',
#    'etag': 'IhauP2e9qNf5bkoc9Q1xc6vFVM8',
#    'id': 'UC6AVa0vSrCpuskzGDDKz_EQ',
#    'snippet': {'title': 'zedstatistics',
#     'description': '',
#     'customUrl': 'zedstatistics',
#     'publishedAt': '2011-07-10T21:04:26Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/4MXG0CX0hBid4xMFasQ2WIaqu-zA8kD927FC-BrTCvrhWCKYP4j3F00QGDzgaYDDlJcwDIJ_uFc=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/4MXG0CX0hBid4xMFasQ2WIaqu-zA8kD927FC-BrTCvrhWCKYP4j3F00QGDzgaYDDlJcwDIJ_uFc=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/4MXG0CX0hBid4xMFasQ2WIaqu-zA8kD927FC-BrTCvrhWCKYP4j3F00QGDzgaYDDlJcwDIJ_uFc=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'zedstatistics', 'description': ''},
#     'country': 'AU'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU6AVa0vSrCpuskzGDDKz_EQ'}},
#    'statistics': {'viewCount': '6868217',
#     'subscriberCount': '113000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '77'}},
#   {'kind': 'youtube#channel',
#    'etag': 'bMOsZbrK26jZluctcPO1QHEbQzQ',
#    'id': 'UCq6XkhO5SZ66N04IcPbqNcw',
#    'snippet': {'title': 'Keith Galli',
#     'description': 'Recent MIT Graduate. I make educational videos on Computer Science, Programming,  Board Games, and more!\n\nI found online videos to be extremely helpful as I progressed through the educational system growing up so I decided to make a channel of my own. Let me know what I should make next!\n\n-Keith :)',
#     'customUrl': 'kgmit',
#     'publishedAt': '2016-12-27T20:18:51Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRQbaN3ZWPGiJOquThlxv1JmxuNaI6iGcBKOdsT5A=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRQbaN3ZWPGiJOquThlxv1JmxuNaI6iGcBKOdsT5A=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRQbaN3ZWPGiJOquThlxv1JmxuNaI6iGcBKOdsT5A=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Keith Galli',
#      'description': 'Recent MIT Graduate. I make educational videos on Computer Science, Programming,  Board Games, and more!\n\nI found online videos to be extremely helpful as I progressed through the educational system growing up so I decided to make a channel of my own. Let me know what I should make next!\n\n-Keith :)'},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUq6XkhO5SZ66N04IcPbqNcw'}},
#    'statistics': {'viewCount': '8644738',
#     'subscriberCount': '136000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '67'}}]}

# %%
def get_channel_stats(youtube,channel_ids):
    all_data=[]
    request=youtube.channels().list(
            part="snippet,contentDetails,statistics",
                id=','.join(channel_ids))
    response=request.execute()
    for i in range(len(response['items'])):
        data=dict(Channel_name=response['items'][i]['snippet']['title'],
              Subscribers=response['items'][i]['statistics']['subscriberCount'],
              Views=response['items'][i]['statistics']['viewCount'],
              Total_videos=response['items'][i]['statistics']['videoCount'],
              playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    return all_data

# %%
channel_statistics=get_channel_stats(youtube,channel_ids)
channel_statistics
# Out:
# [{'Channel_name': 'Analyze With Ali',
#   'Subscribers': '8370',
#   'Views': '257042',
#   'Total_videos': '55',
#   'playlist_id': 'UUaDh-eU-lds_d9kS976vBVw'},
#  {'Channel_name': 'Keith Galli',
#   'Subscribers': '136000',
#   'Views': '8644738',
#   'Total_videos': '67',
#   'playlist_id': 'UUq6XkhO5SZ66N04IcPbqNcw'},
#  {'Channel_name': 'Greg Hogg',
#   'Subscribers': '13000',
#   'Views': '213828',
#   'Total_videos': '215',
#   'playlist_id': 'UUJublDh2UsiIKsAE1553miw'},
#  {'Channel_name': 'zedstatistics',
#   'Subscribers': '113000',
#   'Views': '6868217',
#   'Total_videos': '77',
#   'playlist_id': 'UU6AVa0vSrCpuskzGDDKz_EQ'}]

# %%
channel_data=pd.DataFrame(channel_statistics)
channel_data
# Out:
#        Channel_name Subscribers    Views Total_videos  \
# 0  Analyze With Ali        8370   257042           55
# 1       Keith Galli      136000  8644738           67
# 2         Greg Hogg       13000   213828          215
# 3     zedstatistics      113000  6868217           77
#
#                 playlist_id
# 0  UUaDh-eU-lds_d9kS976vBVw
# 1  UUq6XkhO5SZ66N04IcPbqNcw
# 2  UUJublDh2UsiIKsAE1553miw
# 3  UU6AVa0vSrCpuskzGDDKz_EQ

# %%
channel_data['Subscribers']=pd.to_numeric(channel_data['Subscribers'])
channel_data['Views']=pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']=pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})  #to resize the default output window size
ax=sns.barplot(x='Channel_name',y='Subscribers',data=channel_data)

# %%
ax=sns.barplot(x='Channel_name',y='Views',data=channel_data)

# %%
ax=sns.barplot(x='Channel_name',y='Total_videos',data=channel_data)

# %% [markdown]
# # Function to get Video IDs

# %%
channel_data
# Out:
#        Channel_name  Subscribers    Views  Total_videos  \
# 0  Analyze With Ali         8370   257042            55
# 1       Keith Galli       136000  8644738            67
# 2         Greg Hogg        13000   213828           215
# 3     zedstatistics       113000  6868217            77
#
#                 playlist_id
# 0  UUaDh-eU-lds_d9kS976vBVw
# 1  UUq6XkhO5SZ66N04IcPbqNcw
# 2  UUJublDh2UsiIKsAE1553miw
# 3  UU6AVa0vSrCpuskzGDDKz_EQ

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Greg Hogg', 'playlist_id'].iloc[0]
playlist_id
# Out:
# 'UUJublDh2UsiIKsAE1553miw'

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)
video_ids
# Out:
# ['e-3hXaY0HC0',
#  'bfLm584Cz-M',
#  'II3C0wP8BaI',
#  'KYNuzfn5Fx0',
#  'PxkzRL0LavU',
#  'xIqX1dqcNbY',
#  '1AGuK_8LkGQ',
#  'ZblqTCFnH-M',
#  'wYOH5z_sM50',
#  'XPrq5q-iJyg',
#  'JTK6j6FOjh4',
#  'kGdbPnMCdOg',
#  'H1fi7zaGRfI',
#  'c0k-YLQGKjY',
#  'GbHr_0JrdkI',
#  'cxzWxgVLL0w',
#  '_-UCcuB8nbw',
#  'oLJJI8xn3Hs',
#  'LhveUwahWqQ',
#  '-45K2zhyVOQ',
#  'v1XrLhBH-78',
#  'N_ZVacOdOCs',
#  'h0-ZRqWzXIM',
#  'nJpCfqYDc8U',
#  'Y2NueIHtrWo',
#  'M_Cu7r9gik4',
#  '4-Ob56ESuUs',
#  'ZBEYGCp9O1w',
#  'v1cKMCSS3PY',
#  '3UK0vtQ_pbw',
#  'bGM4AdgnTm8',
#  'kVaP0LeCJWg',
#  '5hA8gHYkhoY',
#  'MlDB-ld24Eg',
#  'rYB9xmVNaks',
#  'NPwl1Vwv8R4',
#  'w6tSluZurPk',
#  '2vaFWZ-M11E',
#  'WqYd9yenEjE',
#  'Cs6OVh9jmCo',
#  '2oyu6H8OB-k',
#  'yIV1PQnnSbw',
#  'aUgsusl7V_E',
#  'UrZuNYtPxFE',
#  'iRLntQAtFJA',
#  'cLjvHL0imhs',
#  'Qp6IfaoZpaU',
#  '13qyCl0_Szg',
#  '-6XN86CjbHI',
#  'pyNYkFeYj7k',
#  'yh_KrcQ1cTU',
#  'Q_AdjdesW_o',
#  'vDVRHCiD5Us',
#  'Wt0i0LJd2BU',
#  'I7Zeqz6YjRE',
#  'NbYzoEZbges',
#  'SLpb9FqpPio',
#  '5t7zu2Uxfd8',
#  'fg7a01eXfME',
#  'mCWnyRY_87g',
#  'sXIFmqAd4Kw',
#  'VUf6TIjc0ug',
#  'tp9cCDlHUz4',
#  'RoggrEzpuMo',
#  '9WbPSMPKPDk',
#  '8F0cWRgqXko',
#  'wJagLfPvbXc',
#  'D16rii8Azuw',
#  'h6MCf89GqCM',
#  'AxZgYs-c1OQ',
#  'h2iwKzha9pw',
#  'I2XlGCeFanA',
#  'TJLbrOkUQng',
#  '8FiWleI-O_w',
#  'g5QgJc7yix8',
#  'HlJoIQe8AoE',
#  'HPp4dNwGCKs',
#  'UWaBNcmx8cI',
#  '1xKpcz61uFw',
#  'FFMlAUf3x_U',
#  'Jd7PL519T5w',
#  '5Dv6wdB5Bzs',
#  'dmGIE2o1QNc',
#  't2eXftjCnBY',
#  'gF6QRnYrYJ8',
#  'JMMYbz0B9xg',
#  'V1a3QQS-iMY',
#  'pEsb3mselDM',
#  'drk81MAMy-E',
#  'olGaKZzSyms',
#  '08G-u9HN8Kc',
#  'gsjEshlJOdE',
#  'j5cqIsE51hM',
#  '9H7-9j9fnNc',
#  'vKBp15E58zI',
#  '6Xsd6O84JJE',
#  '3-pnWVWyH-s',
#  'OzmKVHKOdfA',
#  'ABOqtAn3Ym8',
#  'sW9C-1grE_M',
#  'QHtI4EXLet0',
#  'i5XCMprLdpU',
#  'ZbiXRoxTIh4',
#  'BcIm2g0DISo',
#  'dsgPlXwu93A',
#  'Ew-FEvoRfu4',
#  '73ayzd1-B2s',
#  'UUBP1kQ6ny0',
#  'Xc6g9hR3-U8',
#  'oqiSvNxL_TI',
#  'nu_Uwhn2mHw',
#  'OfMZBi0OA2o',
#  '3l6D2xOsQ2I',
#  'VMzGw4dMUJQ',
#  'YAUbzNK8O9U',
#  'bb_eH-A4HqM',
#  'sYtGMhUuskU',
#  '4xPJcmI51WI',
#  'AQBf6JapAHw',
#  'x7rt9WCVrwg',
#  'wH2hEH8HWtU',
#  'ySPEl5O0mZk',
#  'FRL7DaC_C_E',
#  'rGsTm70fs-0',
#  'G6mPcjPJYZU',
#  'R0oXFdrS1o8',
#  '6Gu3FCVIlc4',
#  '7P6IybYtC50',
#  '-XgFArz_9OY',
#  'Ge_6oqt9QcY',
#  'Dq1szMXgO58',
#  '8cP0PPMtE8c',
#  'UKhmhnA7KwM',
#  'ya4cxuJhujU',
#  'GqN6TR8TfSA',
#  'L5x51zeYxos',
#  '_jFw1OgIyus',
#  'm4g0b09j6u8',
#  'H_jkL388LbY',
#  'PyJJ9eJDd6Q',
#  'mG9okvGMQbA',
#  'nu_4kLpZRK8',
#  '1wI34LDyuDE',
#  '1K-_rXr2AWc',
#  'h3O-epjXTNE',
#  'wV_5x0fkC-I',
#  'NJkmq2C0pj4',
#  'iIwh29JGmmE',
#  'MA27BGM3PRU',
#  '9RmCOup-DvA',
#  'YuE-f6dVGkg',
#  '71gBNnjlK5A',
#  '8m9_t7V9DKM',
#  '5NZvz5L1T1Y',
#  'csKlcRFWzto',
#  'UspZrUl4OXc',
#  'yZ-PB5iXIMM',
#  '2kuU4Sd8xTc',
#  'Rg-bnYog7ek',
#  '4OkuVanFQ6M',
#  'NCiFPCYhGfw',
#  '-U5JPv9LrXQ',
#  'FS-rDleEdtw',
#  'nSkDSzRrewI',
#  '6vKU6b-3MU0',
#  'P0XmNvYLO-8',
#  'Nyxm613JpU4',
#  'q0jSkDGvQAg',
#  '3ORAFgRQhnY',
#  'MaWh-CoDceQ',
#  '9-nTfVtRTuc',
#  'vNK7RpdS0Dc',
#  'RUEomIOiC6I',
#  '_RRaREpxTwk',
#  'M4WaOD4yedA',
#  'kLkYR8pjywc',
#  'gnGu04iwAZU',
#  'E__eD-ZpxHk',
#  '9TwFq_50Uqg',
#  'WRuaEQmVKoY',
#  'WS7oojcvJf8',
#  'L12PUhQiBBM',
#  'gs4zNRkVPCE',
#  'niy_Udf09EI',
#  'RstDaPGiiXU',
#  'zCC_Jgkg8SE',
#  'meoWSu_iCXM',
#  'kF0-zep2m28',
#  'sIky5OUKbqo',
#  'RBXeIubsi2Y',
#  '_xOeiAmzg6k',
#  'AOi3-q2rG_4',
#  'EwegW1LDIrg',
#  'AeyU-oMNjuk',
#  'qNF1HqBvpGE',
#  'rWhETVcV-Y8',
#  'QLQsW8VbTN4',
#  'KnipYx-tcIc',
#  '6tBc5FLKbTI',
#  'zLpVQJ2FB0E',
#  'qkJV-G1FMwg',
#  '7rxqfCq04hQ',
#  'oyOblk_E9_c',
#  'yG6gNqV-REk',
#  'ox-DkDTnkck',
#  '8ypIRp6DPew',
#  'wRJ5cQ9x7Ic',
#  'fcaK5i4cg0Y',
#  'm-jWt7gdyEc',
#  'fVn96Yu6o2w',
#  'mFJIADxR2LQ',
#  'hBTjLjTagpI',
#  'QtBwOi99HUg',
#  'DC3nZRGlIl8',
#  'v7IrZAWiDGg']

# %% [markdown]
# # Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               Dislikes = video['statistics']['dislikeCount'],
                               Comments = video['statistics']['commentCount']
                               )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)
video_details
# Out:
# [{'Title': 'Every Data Scientist Needs THESE 5 Skills.',
#   'Published_date': '2021-11-02T04:02:38Z',
#   'Views': '1169',
#   'Likes': '100',
#   'Dislikes': '0',
#   'Comments': '20'},
#  {'Title': 'Beginner Machine Learning Tutorial: Implementing Logistic Regression in Python... FROM SCRATCH!',
#   'Published_date': '2021-11-01T14:06:34Z',
#   'Views': '358',
#   'Likes': '32',
#   'Dislikes': '1',
#   'Comments': '11'},
#  {'Title': '🔴 LIVE: Ask Anything Data Science / Machine Learning!',
#   'Published_date': '2021-10-30T17:20:42Z',
#   'Views': '443',
#   'Likes': '42',
#   'Dislikes': '1',
#   'Comments': '10'},
#  {'Title': 'Beginner Machine Learning Tutorial: Implementing Multiple Linear Regression in Python.. FROM SCRATCH',
#   'Published_date': '2021-10-30T00:33:46Z',
#   'Views': '784',
#   'Likes': '28',
#   'Dislikes': '1',
#   'Comments': '8'},
#  {'Title': 'Beginner Machine Learning Tutorial: Implementing Simple Linear Regression in Python... FROM SCRATCH',
#   'Published_date': '2021-10-25T23:07:51Z',
#   'Views': '1404',
#   'Likes': '72',
#   'Dislikes': '0',
#   'Comments': '8'},
#  {'Title': 'Scikit-Learn Machine Learning Pipeline Tutorial',
#   'Published_date': '2021-10-22T21:48:58Z',
#   'Views': '756',
#   'Likes': '36',
#   'Dislikes': '0',
#   'Comments': '5'},
#  {'Title': 'K-Fold Cross Validation: Explanation + Tutorial in Python, Scikit-Learn & NumPy',
#   'Published_date': '2021-10-22T01:20:00Z',
#   'Views': '430',
#   'Likes': '24',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Train, Test, & Validation Sets | How to Train Machine Learning Models (Properly!!!)',
#   'Published_date': '2021-10-20T01:51:21Z',
#   'Views': '1182',
#   'Likes': '62',
#   'Dislikes': '0',
#   'Comments': '13'},
#  {'Title': 'How To Label Images For Object Detection & Segmentation | LabelFlow',
#   'Published_date': '2021-10-16T17:31:35Z',
#   'Views': '357',
#   'Likes': '21',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Important Update!',
#   'Published_date': '2021-10-13T22:39:30Z',
#   'Views': '500',
#   'Likes': '32',
#   'Dislikes': '0',
#   'Comments': '18'},
#  {'Title': 'LIVE 🔴: 10,000 Subscriber Data Science PARTY!!!',
#   'Published_date': '2021-10-09T17:59:58Z',
#   'Views': '431',
#   'Likes': '25',
#   'Dislikes': '1',
#   'Comments': '0'},
#  {'Title': 'Multivariate Time Series Forecasting Using LSTM, GRU & 1d CNNs',
#   'Published_date': '2021-10-08T05:01:08Z',
#   'Views': '1874',
#   'Likes': '71',
#   'Dislikes': '1',
#   'Comments': '21'},
#  {'Title': 'Data Scientist vs Data Analyst: Pick The Right One!',
#   'Published_date': '2021-10-05T20:48:22Z',
#   'Views': '515',
#   'Likes': '38',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'LSTM Time Series Forecasting in Python (Beginner)',
#   'Published_date': '2021-10-05T04:07:29Z',
#   'Views': '2224',
#   'Likes': '119',
#   'Dislikes': '0',
#   'Comments': '24'},
#  {'Title': 'Why "Data Scientist" is the BEST Job on Earth.',
#   'Published_date': '2021-10-04T03:03:19Z',
#   'Views': '476',
#   'Likes': '40',
#   'Dislikes': '0',
#   'Comments': '11'},
#  {'Title': "yes, I do love working 80 hours/week - here's how.",
#   'Published_date': '2021-09-23T04:33:51Z',
#   'Views': '780',
#   'Likes': '40',
#   'Dislikes': '1',
#   'Comments': '20'},
#  {'Title': 'Data Science Project Tutorial in Python: Predicting California Housing Prices (Regression)',
#   'Published_date': '2021-09-22T03:27:37Z',
#   'Views': '2663',
#   'Likes': '123',
#   'Dislikes': '1',
#   'Comments': '14'},
#  {'Title': 'Stop Making These 3 Amateur Data Science Mistakes',
#   'Published_date': '2021-09-20T22:09:58Z',
#   'Views': '1420',
#   'Likes': '57',
#   'Dislikes': '6',
#   'Comments': '16'},
#  {'Title': 'End-To-End Machine Learning Project w/ Streamlit - It Only Takes 30 Minutes!',
#   'Published_date': '2021-09-17T04:20:07Z',
#   'Views': '2292',
#   'Likes': '101',
#   'Dislikes': '2',
#   'Comments': '22'},
#  {'Title': 'The Top 10 Questions I Get Asked as a Data Scientist',
#   'Published_date': '2021-09-16T04:08:02Z',
#   'Views': '210',
#   'Likes': '14',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Do THIS to Learn Data Science FAST!',
#   'Published_date': '2021-09-15T05:50:07Z',
#   'Views': '1341',
#   'Likes': '65',
#   'Dislikes': '2',
#   'Comments': '26'},
#  {'Title': 'Data Science Project for Beginners in Python!',
#   'Published_date': '2021-09-12T05:19:06Z',
#   'Views': '2991',
#   'Likes': '148',
#   'Dislikes': '2',
#   'Comments': '15'},
#  {'Title': 'LIVE: Data Science, Machine Learning Ask Anything',
#   'Published_date': '2021-09-12T04:32:41Z',
#   'Views': '249',
#   'Likes': '24',
#   'Dislikes': '1',
#   'Comments': '0'},
#  {'Title': 'Ranking ALL Machine Learning Courses & Books | Best Machine Learning Resources | How to Learn ML',
#   'Published_date': '2021-09-08T21:02:43Z',
#   'Views': '1375',
#   'Likes': '69',
#   'Dislikes': '2',
#   'Comments': '37'},
#  {'Title': 'LIVE: Data Science, Machine Learning Ask Anything',
#   'Published_date': '2021-09-02T04:35:18Z',
#   'Views': '463',
#   'Likes': '24',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Machine Learning Project in Python From Scratch',
#   'Published_date': '2021-08-28T23:24:19Z',
#   'Views': '2456',
#   'Likes': '94',
#   'Dislikes': '0',
#   'Comments': '21'},
#  {'Title': 'LIVE: Data Science, Machine Learning Ask Anything',
#   'Published_date': '2021-08-26T04:42:37Z',
#   'Views': '455',
#   'Likes': '33',
#   'Dislikes': '2',
#   'Comments': '0'},
#  {'Title': 'Logistic Regression | ML Course 3.1',
#   'Published_date': '2021-08-24T16:00:28Z',
#   'Views': '144',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'End to End Data Science Portfolio Project in Python - Exploratory Data Analysis on Covid-19 in India',
#   'Published_date': '2021-08-23T19:40:06Z',
#   'Views': '1924',
#   'Likes': '117',
#   'Dislikes': '1',
#   'Comments': '23'},
#  {'Title': 'Binary Classification | ML Course 3.0',
#   'Published_date': '2021-08-23T14:22:32Z',
#   'Views': '95',
#   'Likes': '8',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Why I Spent So Much Time Talking About Linear Regression | ML Course 2.46',
#   'Published_date': '2021-08-22T16:00:14Z',
#   'Views': '128',
#   'Likes': '10',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Implementing Gradient Descent For Simple Linear Regression In Python / NumPy | ML Course 2.45',
#   'Published_date': '2021-08-21T16:00:17Z',
#   'Views': '145',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Data Science, Machine Learning, Big Data LIVE Q&A!',
#   'Published_date': '2021-08-21T05:20:01Z',
#   'Views': '332',
#   'Likes': '20',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Deriving Gradient Descent For Simple Linear Regression | ML Course 2.44',
#   'Published_date': '2021-08-20T16:00:10Z',
#   'Views': '62',
#   'Likes': '1',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'How To Train & Predict With A Convolutional Neural Network (CNN) In TensorFlow / Keras',
#   'Published_date': '2021-08-19T19:00:34Z',
#   'Views': '177',
#   'Likes': '10',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Gradient Descent For Linear Regression Intuition | ML Course 2.43',
#   'Published_date': '2021-08-19T16:00:08Z',
#   'Views': '73',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Gradient Descent - Intuition | ML Course 2.42',
#   'Published_date': '2021-08-18T16:00:26Z',
#   'Views': '84',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': "Don't Settle. #Shorts",
#   'Published_date': '2021-08-17T21:26:59Z',
#   'Views': '147',
#   'Likes': '17',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Predicting California Housing Prices Part 3 | ML Course 2.41',
#   'Published_date': '2021-08-17T16:00:18Z',
#   'Views': '90',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Predicting California Housing Prices Part 2 | ML Course 2.40',
#   'Published_date': '2021-08-16T16:00:14Z',
#   'Views': '135',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'So What IS A Deep Neural Network? #Shorts',
#   'Published_date': '2021-08-16T05:10:32Z',
#   'Views': '395',
#   'Likes': '37',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'How to Automate Data Analysis In 1 LINE Of Python Code With Pandas Profiling #shorts',
#   'Published_date': '2021-08-15T17:49:44Z',
#   'Views': '1272',
#   'Likes': '113',
#   'Dislikes': '0',
#   'Comments': '20'},
#  {'Title': 'Predicting California Housing Prices Part 1 | ML Course 2.39',
#   'Published_date': '2021-08-15T16:00:01Z',
#   'Views': '121',
#   'Likes': '9',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Introducing Scikit-Learn Linear Model | ML Course 2.38',
#   'Published_date': '2021-08-14T16:00:13Z',
#   'Views': '130',
#   'Likes': '9',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Thank You For The Amazing 5k Party #Shorts',
#   'Published_date': '2021-08-13T21:10:51Z',
#   'Views': '106',
#   'Likes': '13',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': '5k Sub Data Science Party (Games, Quiz, Chat) | Instructions in description!!!',
#   'Published_date': '2021-08-13T18:54:42Z',
#   'Views': '266',
#   'Likes': '21',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Measuring The Test Error | ML Course 2.37',
#   'Published_date': '2021-08-13T16:00:12Z',
#   'Views': '69',
#   'Likes': '1',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Why Are Data Science Memes So BAD????',
#   'Published_date': '2021-08-12T20:54:47Z',
#   'Views': '104',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '7'},
#  {'Title': 'The Importance Of Linear Regression In Machine Learning | ML Course 2.36',
#   'Published_date': '2021-08-12T16:00:00Z',
#   'Views': '75',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'The Motivation Many Aspiring Data Scientists Need',
#   'Published_date': '2021-08-11T23:43:55Z',
#   'Views': '323',
#   'Likes': '35',
#   'Dislikes': '0',
#   'Comments': '25'},
#  {'Title': 'Performing Linear Regression In NumPy | ML Course 2.35',
#   'Published_date': '2021-08-11T16:00:26Z',
#   'Views': '79',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'NumPy Tutorial - Basics In 20 Mins (+ Summary!)',
#   'Published_date': '2021-08-10T21:04:58Z',
#   'Views': '1224',
#   'Likes': '49',
#   'Dislikes': '1',
#   'Comments': '14'},
#  {'Title': 'Generating Random Data In NumPy | ML Course 2.34',
#   'Published_date': '2021-08-10T16:00:33Z',
#   'Views': '52',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Pandas Tutorial - Basics In 20 Mins (+ Summary)',
#   'Published_date': '2021-08-10T02:00:40Z',
#   'Views': '548',
#   'Likes': '31',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Generating Random Data In NumPy | ML Course 2.33',
#   'Published_date': '2021-08-09T16:00:08Z',
#   'Views': '81',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'You Could Be Saving A TON Of Cash On Certificates...',
#   'Published_date': '2021-08-08T19:09:12Z',
#   'Views': '410',
#   'Likes': '19',
#   'Dislikes': '1',
#   'Comments': '19'},
#  {'Title': 'Solving For The Beta Vector NumPy | ML Course 2.32',
#   'Published_date': '2021-08-08T16:00:10Z',
#   'Views': '80',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Beginner Deep Learning Tutorial In Python / TensorFlow / Keras',
#   'Published_date': '2021-08-08T02:29:52Z',
#   'Views': '1003',
#   'Likes': '50',
#   'Dislikes': '2',
#   'Comments': '11'},
#  {'Title': 'Mean Squared Error (MSE) NumPy | ML Course 2.31',
#   'Published_date': '2021-08-07T16:00:22Z',
#   'Views': '78',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Data Science vs ML vs DL vs Neural Nets vs AI vs Big Data vs Analytics vs Statistics',
#   'Published_date': '2021-08-07T15:44:57Z',
#   'Views': '277',
#   'Likes': '22',
#   'Dislikes': '3',
#   'Comments': '10'},
#  {'Title': 'Vectorizing The Predictions | ML Course 2.30',
#   'Published_date': '2021-08-06T16:00:41Z',
#   'Views': '66',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'I Ranked All The Python Data Science Libraries!',
#   'Published_date': '2021-08-06T15:00:17Z',
#   'Views': '537',
#   'Likes': '34',
#   'Dislikes': '1',
#   'Comments': '27'},
#  {'Title': 'Multiple Linear Regression NumPy | ML Course 2.29',
#   'Published_date': '2021-08-05T16:00:36Z',
#   'Views': '129',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Random Livestream #4 Ask Anything Data Science',
#   'Published_date': '2021-08-05T05:55:47Z',
#   'Views': '210',
#   'Likes': '16',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Image Denoiser Convolutional Autoencoder Neural Network Python TensorFlow #CodeItQuick',
#   'Published_date': '2021-08-05T04:11:17Z',
#   'Views': '135',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '1'},
#  {'Title': 'Random Livestream #4 Ask Anything Data Science',
#   'Published_date': '2021-08-05T03:35:49Z',
#   'Views': '118',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '8'},
#  {'Title': 'Vectorization / Parallelization | ML Course 2.28',
#   'Published_date': '2021-08-04T16:00:29Z',
#   'Views': '83',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Autoencoder Dimensionality Reduction Python TensorFlow / Keras #CodeItQuick',
#   'Published_date': '2021-08-04T03:00:05Z',
#   'Views': '114',
#   'Likes': '7',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'PCA Dimensionality Reduction Python Scikit-Learn #CodeItQuick',
#   'Published_date': '2021-08-03T19:00:20Z',
#   'Views': '371',
#   'Likes': '14',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Indexing Arrays In NumPy | ML Course 2.27',
#   'Published_date': '2021-08-03T16:00:03Z',
#   'Views': '104',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Linear Algebra In NumPy | ML Course 2.26',
#   'Published_date': '2021-08-02T16:00:34Z',
#   'Views': '120',
#   'Likes': '8',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Arrays & Shapes In NumPy | ML Course 2.25',
#   'Published_date': '2021-08-01T16:00:16Z',
#   'Views': '145',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Machine Learning Concept Map In 5 Minutes 🤯🤯🤯',
#   'Published_date': '2021-08-01T13:25:46Z',
#   'Views': '110',
#   'Likes': '11',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Introducing The NumPy Library | ML Course 2.24',
#   'Published_date': '2021-07-31T16:00:05Z',
#   'Views': '180',
#   'Likes': '11',
#   'Dislikes': '0',
#   'Comments': '5'},
#  {'Title': "So You're Considering A Masters Of Data Science...",
#   'Published_date': '2021-07-31T14:00:12Z',
#   'Views': '994',
#   'Likes': '43',
#   'Dislikes': '0',
#   'Comments': '14'},
#  {'Title': '1-Layer Neural Network Python TensorFlow / Keras #CodeItQuick',
#   'Published_date': '2021-07-30T18:24:15Z',
#   'Views': '118',
#   'Likes': '8',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Formula For The Beta Vector | ML Course 2.23',
#   'Published_date': '2021-07-30T16:00:08Z',
#   'Views': '120',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Random Forest Classifier Python Scikit-Learn #CodeItQuick',
#   'Published_date': '2021-07-30T04:00:18Z',
#   'Views': '135',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'K-Nearest Neighbors Classifier Python Scikit-Learn #CodeItQuick',
#   'Published_date': '2021-07-30T00:32:26Z',
#   'Views': '116',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'The Gradient (Derivatives) Vector | ML Course 2.22',
#   'Published_date': '2021-07-29T16:00:12Z',
#   'Views': '106',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Making Our Predictions | ML Course 2.21',
#   'Published_date': '2021-07-28T16:00:19Z',
#   'Views': '127',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Design Matrix As Data Storage | ML Course 2.20',
#   'Published_date': '2021-07-27T16:00:05Z',
#   'Views': '154',
#   'Likes': '7',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Motivating Matrices | ML Course 2.19',
#   'Published_date': '2021-07-26T16:00:31Z',
#   'Views': '105',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Random Livestream #3 Ask Anything Data Science',
#   'Published_date': '2021-07-26T05:09:11Z',
#   'Views': '210',
#   'Likes': '25',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Introducing Linear Algebra | ML Course 2.18',
#   'Published_date': '2021-07-25T16:00:14Z',
#   'Views': '129',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Multiple Linear Regression | ML Course 2.17',
#   'Published_date': '2021-07-24T16:00:20Z',
#   'Views': '165',
#   'Likes': '7',
#   'Dislikes': '0',
#   'Comments': '3'},
#  {'Title': 'Random Livestream #2 Ask Anything Machine Learning',
#   'Published_date': '2021-07-24T08:27:49Z',
#   'Views': '156',
#   'Likes': '12',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Testing Out The Model | ML Course 2.16',
#   'Published_date': '2021-07-23T16:00:38Z',
#   'Views': '157',
#   'Likes': '8',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Random Livestream #1 Ask Anything Machine Learning',
#   'Published_date': '2021-07-23T06:58:33Z',
#   'Views': '267',
#   'Likes': '17',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Fitting & Graphing The Model | ML Course 2.15',
#   'Published_date': '2021-07-22T16:00:18Z',
#   'Views': '174',
#   'Likes': '6',
#   'Dislikes': '1',
#   'Comments': '0'},
#  {'Title': 'Coursera Machine Learning Roadmap: Step-by-Step How To Become a Data Scientist',
#   'Published_date': '2021-07-22T05:40:47Z',
#   'Views': '4489',
#   'Likes': '276',
#   'Dislikes': '3',
#   'Comments': '37'},
#  {'Title': 'Generating Random Data | ML Course 2.14',
#   'Published_date': '2021-07-21T16:00:20Z',
#   'Views': '179',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '1'},
#  {'Title': 'Data Generation Intuition | ML Course 2.13',
#   'Published_date': '2021-07-21T05:03:26Z',
#   'Views': '159',
#   'Likes': '9',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Learn Beta 0, Beta 1 In Python | ML Course 2.12',
#   'Published_date': '2021-07-19T16:00:04Z',
#   'Views': '188',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Implementing MSE In Python | ML Course 2.11',
#   'Published_date': '2021-07-18T16:00:34Z',
#   'Views': '254',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'SLR Python Function Definitions | ML Course 2.10',
#   'Published_date': '2021-07-17T16:00:05Z',
#   'Views': '235',
#   'Likes': '6',
#   'Dislikes': '1',
#   'Comments': '0'},
#  {'Title': 'PySpark Tutorial: Spark SQL & DataFrame Basics',
#   'Published_date': '2021-07-16T21:16:12Z',
#   'Views': '3764',
#   'Likes': '144',
#   'Dislikes': '0',
#   'Comments': '31'},
#  {'Title': 'Simple Regression In Python | ML Course 2.9',
#   'Published_date': '2021-07-16T16:00:30Z',
#   'Views': '309',
#   'Likes': '11',
#   'Dislikes': '0',
#   'Comments': '3'},
#  {'Title': 'How I Wake Up WANTING To Learn Data Science',
#   'Published_date': '2021-07-15T18:16:04Z',
#   'Views': '327',
#   'Likes': '21',
#   'Dislikes': '0',
#   'Comments': '13'},
#  {'Title': 'Minimizing The MSE | ML Course 2.8',
#   'Published_date': '2021-07-15T16:00:22Z',
#   'Views': '217',
#   'Likes': '10',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Beta Derivatives of MSE | ML Course 2.7',
#   'Published_date': '2021-07-14T16:00:12Z',
#   'Views': '267',
#   'Likes': '10',
#   'Dislikes': '0',
#   'Comments': '1'},
#  {'Title': "I'm Tired Of Your Data Science Excuses!",
#   'Published_date': '2021-07-14T02:25:59Z',
#   'Views': '210',
#   'Likes': '17',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'MSE Beta Derivatives Intuition | ML Course 2.6',
#   'Published_date': '2021-07-13T16:00:12Z',
#   'Views': '240',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Partial Derivatives Intuition | ML Course 2.5',
#   'Published_date': '2021-07-12T16:00:10Z',
#   'Views': '218',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Calculus Derivative Examples | ML Course 2.4',
#   'Published_date': '2021-07-11T16:00:15Z',
#   'Views': '284',
#   'Likes': '10',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Calculus Derivative Rules | ML Course 2.3',
#   'Published_date': '2021-07-10T16:00:07Z',
#   'Views': '293',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Calculus Derivatives Intuition | ML Course 2.2',
#   'Published_date': '2021-07-09T16:00:08Z',
#   'Views': '477',
#   'Likes': '14',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Regression - Mean Squared Error | ML Course 2.1',
#   'Published_date': '2021-07-08T16:00:25Z',
#   'Views': '560',
#   'Likes': '13',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Simple Linear Regression 1 | ML Course 2.0',
#   'Published_date': '2021-07-07T22:03:00Z',
#   'Views': '618',
#   'Likes': '15',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Supervised vs Unsupervised | ML Course 1.5',
#   'Published_date': '2021-07-07T04:42:18Z',
#   'Views': '567',
#   'Likes': '16',
#   'Dislikes': '0',
#   'Comments': '14'},
#  {'Title': 'Introduction To Clustering | ML Course 1.4',
#   'Published_date': '2021-07-07T04:42:14Z',
#   'Views': '555',
#   'Likes': '10',
#   'Dislikes': '0',
#   'Comments': '3'},
#  {'Title': 'Introduction To Regression | ML Course 1.2',
#   'Published_date': '2021-07-07T04:42:10Z',
#   'Views': '1235',
#   'Likes': '26',
#   'Dislikes': '0',
#   'Comments': '8'},
#  {'Title': 'Introducing Classification | ML Course 1.3',
#   'Published_date': '2021-07-07T04:42:05Z',
#   'Views': '788',
#   'Likes': '13',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'The Machine Learning Lifecycle | ML Course 1.1',
#   'Published_date': '2021-07-07T04:42:01Z',
#   'Views': '1601',
#   'Likes': '37',
#   'Dislikes': '1',
#   'Comments': '5'},
#  {'Title': "Let's Demystify The Buzzwords | ML Course 1.0",
#   'Published_date': '2021-07-07T03:26:33Z',
#   'Views': '2283',
#   'Likes': '55',
#   'Dislikes': '0',
#   'Comments': '10'},
#  {'Title': "Greg Hogg's Machine Learning Course In Python",
#   'Published_date': '2021-07-07T03:26:29Z',
#   'Views': '6248',
#   'Likes': '240',
#   'Dislikes': '1',
#   'Comments': '23'},
#  {'Title': 'GITHUB JUST AUTOMATED MACHINE LEARNING',
#   'Published_date': '2021-07-02T19:02:38Z',
#   'Views': '376',
#   'Likes': '16',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'How To Become A Data Scientist In 6 Clear Steps',
#   'Published_date': '2021-07-02T04:35:07Z',
#   'Views': '504',
#   'Likes': '32',
#   'Dislikes': '0',
#   'Comments': '11'},
#  {'Title': 'How I Build Amazing Data Science Projects',
#   'Published_date': '2021-06-30T19:53:49Z',
#   'Views': '1040',
#   'Likes': '52',
#   'Dislikes': '1',
#   'Comments': '7'},
#  {'Title': 'SQL For Data Scientists: Basics in 30 Minutes',
#   'Published_date': '2021-06-29T21:28:49Z',
#   'Views': '2031',
#   'Likes': '98',
#   'Dislikes': '2',
#   'Comments': '13'},
#  {'Title': '5 Things You WISH You Knew About Coursera',
#   'Published_date': '2021-06-28T22:48:33Z',
#   'Views': '905',
#   'Likes': '30',
#   'Dislikes': '4',
#   'Comments': '8'},
#  {'Title': 'REVIEW: Andrew Ng Deep Learning Specialization',
#   'Published_date': '2021-06-28T04:46:51Z',
#   'Views': '1141',
#   'Likes': '21',
#   'Dislikes': '2',
#   'Comments': '11'},
#  {'Title': 'If I Could Pick ONLY 1 Domain In Data Science #shorts',
#   'Published_date': '2021-06-27T05:00:03Z',
#   'Views': '206',
#   'Likes': '17',
#   'Dislikes': '1',
#   'Comments': '0'},
#  {'Title': 'If I Could Pick ONLY 1 Data Science Library #shorts',
#   'Published_date': '2021-06-26T05:00:21Z',
#   'Views': '144',
#   'Likes': '11',
#   'Dislikes': '1',
#   'Comments': '0'},
#  {'Title': 'If I Could Pick ONLY 1 Data Science Certificate #shorts',
#   'Published_date': '2021-06-25T05:30:03Z',
#   'Views': '544',
#   'Likes': '20',
#   'Dislikes': '1',
#   'Comments': '11'},
#  {'Title': 'My Data Science Interview Failures',
#   'Published_date': '2021-06-24T04:19:27Z',
#   'Views': '218',
#   'Likes': '15',
#   'Dislikes': '1',
#   'Comments': '6'},
#  {'Title': 'FULL REVIEW: Google Data Analytics Certificate',
#   'Published_date': '2021-06-22T04:00:04Z',
#   'Views': '1294',
#   'Likes': '20',
#   'Dislikes': '2',
#   'Comments': '6'},
#  {'Title': 'Your First Python Classification Project: Titanic',
#   'Published_date': '2021-06-21T04:58:39Z',
#   'Views': '997',
#   'Likes': '41',
#   'Dislikes': '1',
#   'Comments': '10'},
#  {'Title': 'Do You Need University Education To Get A ML Job?',
#   'Published_date': '2021-06-19T19:23:05Z',
#   'Views': '136',
#   'Likes': '10',
#   'Dislikes': '0',
#   'Comments': '5'},
#  {'Title': 'FULL REVIEW - IBM Data Science Certificate',
#   'Published_date': '2021-06-17T16:17:07Z',
#   'Views': '5489',
#   'Likes': '142',
#   'Dislikes': '7',
#   'Comments': '55'},
#  {'Title': 'The Statistics You ACTUALLY Need For ML',
#   'Published_date': '2021-06-16T05:00:06Z',
#   'Views': '247',
#   'Likes': '20',
#   'Dislikes': '0',
#   'Comments': '9'},
#  {'Title': 'Do You Need Spark To Get A Job In Data Science?',
#   'Published_date': '2021-06-15T21:09:50Z',
#   'Views': '192',
#   'Likes': '14',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Is Machine Learning Worth Learning In 2021?',
#   'Published_date': '2021-06-14T21:38:06Z',
#   'Views': '562',
#   'Likes': '20',
#   'Dislikes': '0',
#   'Comments': '10'},
#  {'Title': 'Machine Learning vs Deep Learning (Coursera)',
#   'Published_date': '2021-06-13T21:20:50Z',
#   'Views': '210',
#   'Likes': '9',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Everything Data Science, ML, Big Data In 30 Mins',
#   'Published_date': '2021-06-12T20:09:56Z',
#   'Views': '183',
#   'Likes': '12',
#   'Dislikes': '3',
#   'Comments': '7'},
#  {'Title': 'The Best Data Science Certificates To Stand Out',
#   'Published_date': '2021-06-11T22:32:46Z',
#   'Views': '1351',
#   'Likes': '38',
#   'Dislikes': '1',
#   'Comments': '10'},
#  {'Title': 'Why You Failed Your Data Science Interview',
#   'Published_date': '2021-06-09T20:30:40Z',
#   'Views': '289',
#   'Likes': '13',
#   'Dislikes': '0',
#   'Comments': '8'},
#  {'Title': 'I Got A Green Screen!',
#   'Published_date': '2021-06-08T19:13:14Z',
#   'Views': '75',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'File IO - Reading (Python Master Class 3b)',
#   'Published_date': '2021-06-07T20:22:36Z',
#   'Views': '72',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'File IO - Writing (Python Master Class 3c)',
#   'Published_date': '2021-06-07T20:22:20Z',
#   'Views': '46',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Function Tricks (Python Master Class 3a)',
#   'Published_date': '2021-06-07T20:22:02Z',
#   'Views': '117',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Module 3 Final Project (Python Master Class)',
#   'Published_date': '2021-06-07T20:21:51Z',
#   'Views': '128',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'User Input 1 (Python Master Class 3d)',
#   'Published_date': '2021-06-07T20:21:39Z',
#   'Views': '37',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'User Input 2 (Python Master Class 3e)',
#   'Published_date': '2021-06-07T20:21:23Z',
#   'Views': '42',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Welcome To Module 3 (Python Master Class)',
#   'Published_date': '2021-06-07T20:21:12Z',
#   'Views': '257',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'THIS IS HUGE - AWS Data Science Specialization',
#   'Published_date': '2021-06-03T15:02:36Z',
#   'Views': '1072',
#   'Likes': '34',
#   'Dislikes': '2',
#   'Comments': '15'},
#  {'Title': 'Dictionaries (Python Master Class 2b)',
#   'Published_date': '2021-06-02T20:35:52Z',
#   'Views': '81',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Lists In Depth (Python Master Class 2a)',
#   'Published_date': '2021-06-02T20:35:38Z',
#   'Views': '157',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Module 2 Final Project (Python Master Class)',
#   'Published_date': '2021-06-02T20:35:28Z',
#   'Views': '63',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Mutation In Functions (Python Master Class 2e)',
#   'Published_date': '2021-06-02T20:35:14Z',
#   'Views': '57',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Sets (Python Master Class 2c)',
#   'Published_date': '2021-06-02T20:35:03Z',
#   'Views': '65',
#   'Likes': '2',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Strings In Depth (Python Master Class 2f)',
#   'Published_date': '2021-06-02T20:34:53Z',
#   'Views': '59',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Tuples (Python Master Class 2d)',
#   'Published_date': '2021-06-02T20:34:38Z',
#   'Views': '57',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Types Summary (Python Master Class Module 2g)',
#   'Published_date': '2021-06-02T20:34:26Z',
#   'Views': '49',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Welcome To Module 2 (Python Master Class)',
#   'Published_date': '2021-06-02T20:34:03Z',
#   'Views': '322',
#   'Likes': '15',
#   'Dislikes': '0',
#   'Comments': '1'},
#  {'Title': 'How I Became A Data Scientist (My Untold Story)',
#   'Published_date': '2021-05-31T03:06:43Z',
#   'Views': '488',
#   'Likes': '41',
#   'Dislikes': '0',
#   'Comments': '20'},
#  {'Title': "Greg Hogg's Python Master Class (Full Course)",
#   'Published_date': '2021-05-29T19:30:54Z',
#   'Views': '886',
#   'Likes': '24',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Welcome To Module 1 (Python Master Class)',
#   'Published_date': '2021-05-29T19:26:23Z',
#   'Views': '411',
#   'Likes': '6',
#   'Dislikes': '1',
#   'Comments': '0'},
#  {'Title': 'Core Data Types (Python Master Class 1b)',
#   'Published_date': '2021-05-29T19:25:19Z',
#   'Views': '238',
#   'Likes': '11',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Google Colab (Python Master Class 1a)',
#   'Published_date': '2021-05-29T19:25:05Z',
#   'Views': '385',
#   'Likes': '7',
#   'Dislikes': '1',
#   'Comments': '4'},
#  {'Title': 'Basic Arithmetic (Python Master Class 1g)',
#   'Published_date': '2021-05-29T19:24:49Z',
#   'Views': '115',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Comparison Operators (Python Master Class 1n)',
#   'Published_date': '2021-05-29T19:24:33Z',
#   'Views': '75',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Conditionals / If Else (Python Master Class 1i)',
#   'Published_date': '2021-05-29T19:24:21Z',
#   'Views': '128',
#   'Likes': '7',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'For Loops: Part 1 (Python Master Class 1d)',
#   'Published_date': '2021-05-29T19:24:10Z',
#   'Views': '159',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'For Loops: Part 2 (Python Master Class 1e)',
#   'Published_date': '2021-05-29T19:23:54Z',
#   'Views': '126',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '2'},
#  {'Title': 'Functions: Part 1 (Python Master Class 1j)',
#   'Published_date': '2021-05-29T19:23:36Z',
#   'Views': '114',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Functions: Part 2 (Python Master Class 1k)',
#   'Published_date': '2021-05-29T19:23:18Z',
#   'Views': '92',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Functions: Part 3 (Python Master Class 1l)',
#   'Published_date': '2021-05-29T19:23:04Z',
#   'Views': '87',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Functions: Part 4 (Python Master Class 1m)',
#   'Published_date': '2021-05-29T19:22:48Z',
#   'Views': '85',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Python Lists (Python Master Class 1c)',
#   'Published_date': '2021-05-29T19:22:29Z',
#   'Views': '182',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'The Range Function (Python Master Class 1o)',
#   'Published_date': '2021-05-29T19:22:16Z',
#   'Views': '82',
#   'Likes': '3',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'String Concatenation (Python Master Class 1p)',
#   'Published_date': '2021-05-29T19:21:48Z',
#   'Views': '76',
#   'Likes': '4',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'While Loops (Python Master Class 1h)',
#   'Published_date': '2021-05-29T19:18:48Z',
#   'Views': '105',
#   'Likes': '5',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Variables (Python Master Class 1f)',
#   'Published_date': '2021-05-29T19:18:26Z',
#   'Views': '115',
#   'Likes': '6',
#   'Dislikes': '0',
#   'Comments': '0'},
#  {'Title': 'Module 1 Final Project (Python Master Class)',
#   'Published_date': '2021-05-29T19:17:48Z',
#   'Views': '168',
#   'Likes': '9',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Best Laptop Specs For Machine Learning In 2021',
#   'Published_date': '2021-05-25T03:03:35Z',
#   'Views': '2111',
#   'Likes': '45',
#   'Dislikes': '3',
#   'Comments': '35'},
#  {'Title': 'The Ultimate Advice For Every Data Science Student',
#   'Published_date': '2021-05-22T19:47:52Z',
#   'Views': '466',
#   'Likes': '19',
#   'Dislikes': '1',
#   'Comments': '7'},
#  {'Title': 'Create An Image Classifier In TensorFlow & Keras',
#   'Published_date': '2021-05-21T19:59:42Z',
#   'Views': '1110',
#   'Likes': '40',
#   'Dislikes': '0',
#   'Comments': '18'},
#  {'Title': 'Clustering Explained In 20 Seconds',
#   'Published_date': '2021-05-19T19:24:29Z',
#   'Views': '165',
#   'Likes': '8',
#   'Dislikes': '1',
#   'Comments': '1'},
#  {'Title': 'Transfer Learning In Computer Vision',
#   'Published_date': '2021-05-19T18:26:59Z',
#   'Views': '153',
#   'Likes': '11',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': '3 Data Science Skills Changed Everything',
#   'Published_date': '2021-05-19T00:23:16Z',
#   'Views': '408',
#   'Likes': '27',
#   'Dislikes': '0',
#   'Comments': '9'},
#  {'Title': 'Overfitting & Underfitting Explained Simply',
#   'Published_date': '2021-05-18T20:07:33Z',
#   'Views': '247',
#   'Likes': '11',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'This Data Scientist Could Be You',
#   'Published_date': '2021-05-14T18:01:04Z',
#   'Views': '155',
#   'Likes': '14',
#   'Dislikes': '0',
#   'Comments': '11'},
#  {'Title': 'Is A Certificate In Data Science Worth it?',
#   'Published_date': '2021-05-14T03:59:49Z',
#   'Views': '225',
#   'Likes': '16',
#   'Dislikes': '0',
#   'Comments': '5'},
#  {'Title': 'Supervised Learning & Neural Networks In Python',
#   'Published_date': '2021-05-13T18:40:25Z',
#   'Views': '269',
#   'Likes': '13',
#   'Dislikes': '0',
#   'Comments': '3'},
#  {'Title': "Why You're Not Getting A Data Science Job",
#   'Published_date': '2021-05-12T15:56:57Z',
#   'Views': '960',
#   'Likes': '36',
#   'Dislikes': '4',
#   'Comments': '18'},
#  {'Title': 'Detecting Outliers In Pokemon',
#   'Published_date': '2021-05-11T17:46:47Z',
#   'Views': '490',
#   'Likes': '13',
#   'Dislikes': '1',
#   'Comments': '4'},
#  {'Title': 'Why I Never Get Burnt Out Doing Data Science',
#   'Published_date': '2021-05-10T20:08:40Z',
#   'Views': '1444',
#   'Likes': '65',
#   'Dislikes': '6',
#   'Comments': '19'},
#  {'Title': 'Data Science: Python Vs R',
#   'Published_date': '2021-05-05T21:06:03Z',
#   'Views': '231',
#   'Likes': '10',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Machine Learning Coding For 24 Hours Straight',
#   'Published_date': '2021-05-03T03:30:02Z',
#   'Views': '3267',
#   'Likes': '108',
#   'Dislikes': '8',
#   'Comments': '12'},
#  {'Title': 'Data Science Professional Certifications Ranked',
#   'Published_date': '2021-04-21T19:03:15Z',
#   'Views': '20986',
#   'Likes': '722',
#   'Dislikes': '19',
#   'Comments': '138'},
#  {'Title': 'Essential Neural Network Layers In Keras',
#   'Published_date': '2021-04-21T05:58:25Z',
#   'Views': '382',
#   'Likes': '14',
#   'Dislikes': '0',
#   'Comments': '5'},
#  {'Title': 'Host Machine Learning App Free On Heroku',
#   'Published_date': '2021-04-17T15:46:13Z',
#   'Views': '2180',
#   'Likes': '115',
#   'Dislikes': '0',
#   'Comments': '20'},
#  {'Title': 'How To Learn Machine Learning In 2021',
#   'Published_date': '2021-04-09T07:01:36Z',
#   'Views': '1122',
#   'Likes': '60',
#   'Dislikes': '0',
#   'Comments': '16'},
#  {'Title': 'Python Flask Machine Learning Web App Tutorial',
#   'Published_date': '2021-04-02T16:39:40Z',
#   'Views': '20245',
#   'Likes': '746',
#   'Dislikes': '5',
#   'Comments': '90'},
#  {'Title': 'Build A Neural Net In Under 4 Minutes',
#   'Published_date': '2021-03-29T06:01:00Z',
#   'Views': '2143',
#   'Likes': '99',
#   'Dislikes': '3',
#   'Comments': '10'},
#  {'Title': 'Apache Spark / PySpark Tutorial: Basics In 15 Mins',
#   'Published_date': '2021-03-25T22:42:20Z',
#   'Views': '22439',
#   'Likes': '609',
#   'Dislikes': '12',
#   'Comments': '49'},
#  {'Title': 'Python Coding Introduction For Beginners',
#   'Published_date': '2021-03-19T06:17:24Z',
#   'Views': '554',
#   'Likes': '17',
#   'Dislikes': '0',
#   'Comments': '5'},
#  {'Title': 'Step By Step Data Science Roadmap In 2021',
#   'Published_date': '2021-03-18T02:45:26Z',
#   'Views': '1459',
#   'Likes': '55',
#   'Dislikes': '1',
#   'Comments': '42'},
#  {'Title': 'Best Data Science Coding Environment #Shorts',
#   'Published_date': '2021-03-17T16:15:01Z',
#   'Views': '441',
#   'Likes': '17',
#   'Dislikes': '1',
#   'Comments': '6'},
#  {'Title': '21 Data Science Projects To Get Hired In 2021',
#   'Published_date': '2021-03-16T05:45:48Z',
#   'Views': '2994',
#   'Likes': '109',
#   'Dislikes': '6',
#   'Comments': '8'},
#  {'Title': 'Data Science Final Project In Python',
#   'Published_date': '2021-03-14T12:52:02Z',
#   'Views': '7774',
#   'Likes': '339',
#   'Dislikes': '4',
#   'Comments': '23'},
#  {'Title': 'Top 5 Mistakes Aspiring Data Scientists Make',
#   'Published_date': '2021-03-10T05:34:27Z',
#   'Views': '8630',
#   'Likes': '540',
#   'Dislikes': '10',
#   'Comments': '62'},
#  {'Title': 'Your First Machine Learning Project In Python',
#   'Published_date': '2021-03-06T22:29:57Z',
#   'Views': '3846',
#   'Likes': '170',
#   'Dislikes': '2',
#   'Comments': '9'},
#  {'Title': 'Feedback For Passing Your Data Science Interview',
#   'Published_date': '2021-03-02T22:18:41Z',
#   'Views': '2259',
#   'Likes': '81',
#   'Dislikes': '5',
#   'Comments': '11'},
#  {'Title': 'Big Data & Apache Spark',
#   'Published_date': '2021-02-27T00:02:42Z',
#   'Views': '1307',
#   'Likes': '79',
#   'Dislikes': '4',
#   'Comments': '12'},
#  {'Title': 'How I Got 20 Data Science Interviews In A Week',
#   'Published_date': '2021-02-24T00:18:54Z',
#   'Views': '1968',
#   'Likes': '102',
#   'Dislikes': '4',
#   'Comments': '17'},
#  {'Title': 'Python Scientific Libraries (SciPy Stack)',
#   'Published_date': '2021-02-21T16:03:15Z',
#   'Views': '1193',
#   'Likes': '46',
#   'Dislikes': '0',
#   'Comments': '17'},
#  {'Title': 'Data Science Vs. Deep Learning',
#   'Published_date': '2021-02-19T02:32:55Z',
#   'Views': '449',
#   'Likes': '21',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'K-Means Clustering: Unsupervised Learning',
#   'Published_date': '2021-02-18T01:39:33Z',
#   'Views': '180',
#   'Likes': '16',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Relational Databases & SQL',
#   'Published_date': '2021-02-16T00:48:44Z',
#   'Views': '1839',
#   'Likes': '71',
#   'Dislikes': '0',
#   'Comments': '8'},
#  {'Title': 'The Best Markov Chain Explanation',
#   'Published_date': '2021-02-13T19:26:03Z',
#   'Views': '361',
#   'Likes': '20',
#   'Dislikes': '0',
#   'Comments': '6'},
#  {'Title': 'Reinforcement Learning S & B: Computing Averages',
#   'Published_date': '2021-02-12T23:12:49Z',
#   'Views': '102',
#   'Likes': '11',
#   'Dislikes': '0',
#   'Comments': '4'},
#  {'Title': 'Reinforcement Learning S & B: K-Armed Bandits',
#   'Published_date': '2021-02-11T06:25:33Z',
#   'Views': '180',
#   'Likes': '16',
#   'Dislikes': '0',
#   'Comments': '3'},
#  {'Title': 'Reinforcement Learning S & B: Introduction',
#   'Published_date': '2021-02-11T06:08:50Z',
#   'Views': '247',
#   'Likes': '17',
#   'Dislikes': '0',
#   'Comments': '4'}]

# %%
video_data = pd.DataFrame(video_details)
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Dislikes'] = pd.to_numeric(video_data['Dislikes'])
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0           Every Data Scientist Needs THESE 5 Skills.     2021-11-02   1169
# 1    Beginner Machine Learning Tutorial: Implementi...     2021-11-01    358
# 2    🔴 LIVE: Ask Anything Data Science / Machine Le...     2021-10-30    443
# 3    Beginner Machine Learning Tutorial: Implementi...     2021-10-30    784
# 4    Beginner Machine Learning Tutorial: Implementi...     2021-10-25   1404
# ..                                                 ...            ...    ...
# 210                         Relational Databases & SQL     2021-02-16   1839
# 211                  The Best Markov Chain Explanation     2021-02-13    361
# 212   Reinforcement Learning S & B: Computing Averages     2021-02-12    102
# 213      Reinforcement Learning S & B: K-Armed Bandits     2021-02-11    180
# 214         Reinforcement Learning S & B: Introduction     2021-02-11    247
#
#      Likes  Dislikes Comments
# 0      100         0       20
# 1       32         1       11
# 2       42         1       10
# 3       28         1        8
# 4       72         0        8
# ..     ...       ...      ...
# 210     71         0        8
# 211     20         0        6
# 212     11         0        4
# 213     16         0        3
# 214     17         0        4
#
# [215 rows x 6 columns]

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)
top10_videos
# Out:
#                                                  Title Published_date  Views  \
# 196  Apache Spark / PySpark Tutorial: Basics In 15 ...     2021-03-25  22439
# 190    Data Science Professional Certifications Ranked     2021-04-21  20986
# 194     Python Flask Machine Learning Web App Tutorial     2021-04-02  20245
# 202       Top 5 Mistakes Aspiring Data Scientists Make     2021-03-10   8630
# 201               Data Science Final Project In Python     2021-03-14   7774
# 115      Greg Hogg's Machine Learning Course In Python     2021-07-07   6248
# 129         FULL REVIEW - IBM Data Science Certificate     2021-06-17   5489
# 90   Coursera Machine Learning Roadmap: Step-by-Ste...     2021-07-22   4489
# 203      Your First Machine Learning Project In Python     2021-03-06   3846
# 96      PySpark Tutorial: Spark SQL & DataFrame Basics     2021-07-16   3764
#
#      Likes  Dislikes Comments
# 196    609        12       49
# 190    722        19      138
# 194    746         5       90
# 202    540        10       62
# 201    339         4       23
# 115    240         1       23
# 129    142         7       55
# 90     276         3       37
# 203    170         2        9
# 96     144         0       31

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)
